# %% [markdown]
# <a href="https://colab.research.google.com/github/pedroluccasanticioli-byte/lucca-santicioli/blob/main/1404.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numero = int (input ("Digite um numero de 0-10:"))

if numero == 0:
  print (f"Este numero é par")

elif numero == 1:
  print (f"Este numero é impar")

elif numero == 2:
  print (f"Este numero é par")

elif numero == 3:
  print (f"Este numero é impar")

elif numero == 4:
  print (f"Este numero é par")

elif numero == 5:
  print (f"Este numero é impar")

elif numero == 6:
  print (f"Este numero é par")

elif numero == 7:
  print (f"Este numero é impar")

elif numero == 8:
  print (f"Este numero é par")

elif numero == 9:
  print (f"Este numero é impar")

elif numero == 10:
  print (f"Este numero é par")
# Out:
# Digite um numero de 0-10:7
# Este numero é impar

# %%
numero1 = int (input("digite um numero:"))
numero2 = int (input("digite um numero:"))

#processamento e saida

if numero1 > numero2:
  print (f"o numero {numero1} é maior que o numero {numero2}.")

elif numero1 == numero2:
  print (f"o numero {numero1} é igual ao numero {numero2}.")

else:
    print (f"o numero {numero1} é menor que o numero {numero2}.")
# Out:
# digite um numero:67
# digite um numero:67
# o numero 67 é igual ao numero 67.

# %%
nota = int (input("digite uma nota:"))

if nota < 5:
  print(f"voce reprovou meu mano e se foi abaixo de 0 voce ta de sacanagem, errou até o nome mano")

elif nota >= 5:
  print (f"voce pode recuperar mano")

elif nota >= 7:
  print (f"voce pasou meu nego, mas se passou de 10, tu es sabido")
# Out:
# digite uma nota:9
# voce pode recuperar mano
