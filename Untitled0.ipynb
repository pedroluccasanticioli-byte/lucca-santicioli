# %% [markdown]
# <a href="https://colab.research.google.com/github/pedroluccasanticioli-byte/lucca-santicioli/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#faça um programa que leia dois numeros e mostre o resultado da soma.

num1 = float(input("Digite o primeiro número: "))
num2 = float(input("Digite o segundo número: "))

soma = num1 + num2

print(f"O resultado da soma é: {soma}")
# Out:
# Digite o primeiro número: 67
# Digite o segundo número: 42
# O resultado da soma é: 109.0

# %%
#faça um programa que leia dois numeros e calcula e calcule a multiplicação entre eles.

# %%
#peça ao usuario duas notas e calcule a media.

# %%
#leia um numero e mostre:

#o dobro;
#o triplo.

# %%
#leia opreço de um produto e a quantidade comprada. depois , calcule o valor total da compra.
