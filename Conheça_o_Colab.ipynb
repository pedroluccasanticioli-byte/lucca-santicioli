# %% [markdown]
# <a href="https://colab.research.google.com/github/pedroluccasanticioli-byte/lucca-santicioli/blob/main/Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Olá mundo!")
print ("Olá mundo!")
print ("Olá mundo!")
print ("Olá mundo!")
print ("Olá mundo!")
print ("Olá mundo!")
# Out:
# Olá mundo!
# Olá mundo!
# Olá mundo!

# %%
for i in range (0, 11, 2):
  print (i)
# Out:
# 0
# 2
# 4
# 6
# 8
# 10

# %%
palavra = "SIX SEVEEEEN67"

for i in (palavra):
  print (i)
# Out:
# S
# I
# X
#
# S
# E
# V
# E
# E
# E
# E
# N
# 6
# 7

# %%
palavra =  str (input("Digite uma palavra ou frase:"))
invertida = ""
for i in (palavra):
  print (palavra)
# Out:
# Digite uma palavra ou frase:SIX SEVEEEEEENNNN
# SIX SEVEEEEEENNNN
# SIX SEVEEEEEENNNN
# SIX SEVEEEEEENNNN
# SIX SEVEEEEEENNNN
# SIX SEVEEEEEENNNN
# SIX SEVEEEEEENNNN
# SIX SEVEEEEEENNNN
# SIX SEVEEEEEENNNN
# SIX SEVEEEEEENNNN
# SIX SEVEEEEEENNNN
# SIX SEVEEEEEENNNN
# SIX SEVEEEEEENNNN
# SIX SEVEEEEEENNNN
# SIX SEVEEEEEENNNN
# SIX SEVEEEEEENNNN
# SIX SEVEEEEEENNNN
# SIX SEVEEEEEENNNN

# %%
palavra = str (input("Digite uma palavra ou frase:"))
invertida = ""
for i in (palavra):
  invertida = i + invertida
print (invertida)
# Out:
# Digite uma palavra ou frase:oi
# io

# %%
# Escrever um programa que imprime os numeros de 10 até 0
# Out:
# Digite um numero de 10 até 0:5
# 5
